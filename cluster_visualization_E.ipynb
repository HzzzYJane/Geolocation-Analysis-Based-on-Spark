# %%
# !pip install folium
import pandas as pd
import glob
import folium
# Out:
# Collecting folium
#   Downloading https://files.pythonhosted.org/packages/fd/a0/ccb3094026649cda4acd55bf2c3822bb8c277eb11446d13d384e5be35257/folium-0.10.1-py2.py3-none-any.whl (91kB)
#      |████████████████████████████████| 92kB 3.7MB/s eta 0:00:011
# Collecting branca>=0.3.0
#   Downloading https://files.pythonhosted.org/packages/63/36/1c93318e9653f4e414a2e0c3b98fc898b4970e939afeedeee6075dd3b703/branca-0.3.1-py3-none-any.whl
# Requirement already satisfied: jinja2>=2.9 in /anaconda3/lib/python3.7/site-packages (from folium) (2.10)
# Requirement already satisfied: numpy in /anaconda3/lib/python3.7/site-packages (from folium) (1.17.1)
# Requirement already satisfied: requests in /anaconda3/lib/python3.7/site-packages (from folium) (2.19.1)
# Requirement already satisfied: six in /anaconda3/lib/python3.7/site-packages (from branca>=0.3.0->folium) (1.11.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /anaconda3/lib/python3.7/site-packages (from jinja2>=2.9->folium) (1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda3/lib/python3.7/site-packages (from requests->folium) (2018.8.24)
# Requirement already satisfied: urllib3<1.24,>=1.21.1 in /anaconda3/lib/python3.7/site-packages (from requests->folium) (1.23)
# Requirement already satisfied: idna<2.8,>=2.5 in /anaconda3/lib/python3.7/site-packages (from requests->folium) (2.7)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /anaconda3/lib/python3.7/site-packages (from requests->folium) (3.0.4)
# Installing collected packages: branca, folium
# Successfully installed branca-0.3.1 folium-0.10.1

# %%
# cluster visualzie #Euclidean k=2
latitude=40.428
longitude=-74.1
dir_E2 = glob.glob('/Users/hanzheyu/Desktop/CSE427-project/NY_pickup/result2E/2E/points/*.txt')
df = pd.concat([pd.read_csv(f, sep=" ", header=None) for f in dir_E2])
df.rename({0:'classify', 1: 'lat', 2: 'lon'})
df.columns = ['classify','lat', 'lon']
df = df.iloc[1:25000,[0,1,2]]

df0 = df[df.classify==0]

df1 = df[df.classify==1]

incidents=folium.map.FeatureGroup()

for lat,lon, in zip(df0.lat,df0.lon):
        incidents.add_child(
            folium.CircleMarker(
            [lat,lon],
            radius=0.1,
            color='blue',
            fill=True,
            fill_color='blue',
            fill_opacity=4
            )
        
        )
for lat,lon, in zip(df1.lat,df1.lon):
        incidents.add_child(
            folium.CircleMarker(
            [lat,lon],
            radius=0.1,
            color='green',
            fill=True,
            fill_color='green',
            fill_opacity=4
            )     
        )

# m = folium.Map(location=[39.712183, -104.998424], zoom_start=5)
# point_layer = folium.FeatureGroup(name="Query Search")


ny_map=folium.Map(location=[latitude,longitude],zoom_start=12)
ny_map.add_child(incidents)
point_layer = folium.FeatureGroup(name="Query Search")

latLong = [(40.7127325084, -73.830401655,"first cluster"),
           (40.7527417768, -73.9809464178,"second cluster")]

for lat,lng,nameP in latLong:
    point_layer.add_child(folium.CircleMarker(location=[lat, lng], radius=2,
        popup=str(nameP) + " Lat: " + str(lat) + " , Long: " + str(lng), 
        tooltip=str(nameP) + " Lat: " + str(lat) + " , Long: " + str(lng),
        fill=True,  # Set fill to True
        color='red',
        fill_opacity=1)).add_to(ny_map)
    
ny_map.add_child(point_layer)
ny_map.add_child(folium.LayerControl()) 
    
ny_map.save("mymapE2.html")

# %%
# cluster visualzie #Euclidean k=3
latitude=40.428
longitude=-74.1
dir_E3 = glob.glob('/Users/hanzheyu/Desktop/CSE427-project/NY_pickup/result3E/3E/points/*.txt')
df = pd.concat([pd.read_csv(f, sep=" ", header=None) for f in dir_E3])
df.rename({0:'classify', 1: 'lat', 2: 'lon'})
df.columns = ['classify','lat', 'lon']
df = df.iloc[1:25000,[0,1,2]]
df0 = df[df.classify==0]

df1 = df[df.classify==1]

df2 = df[df.classify==2]

incidents=folium.map.FeatureGroup()

for lat,lon, in zip(df0.lat,df0.lon):
        incidents.add_child(
            folium.CircleMarker(
            [lat,lon],
            radius=0.1,
            color='yellow',
            fill=True,
            fill_color='yellow',
            fill_opacity=4
            )
 )
        
for lat,lon, in zip(df1.lat,df1.lon):
        incidents.add_child(
            folium.CircleMarker(
            [lat,lon],
            radius=0.1,
            color='blue',
            fill=True,
            fill_color='blue',
            fill_opacity=4
            )
        
        )
for lat,lon, in zip(df2.lat,df2.lon):
        incidents.add_child(
            folium.CircleMarker(
            [lat,lon],
            radius=0.1,
            color='green',
            fill=True,
            fill_color='green',
            fill_opacity=4
            )
        
        )

# m = folium.Map(location=[39.712183, -104.998424], zoom_start=5)
# point_layer = folium.FeatureGroup(name="Query Search")


ny_map=folium.Map(location=[latitude,longitude],zoom_start=12)
ny_map.add_child(incidents)
point_layer = folium.FeatureGroup(name="Query Search")

latLong = [(40.7122329221, -73.8297279616,"first cluster"),
           (40.7348423549, -73.9929854565,"second cluster"),
           (40.7698986594, -73.9693341084,"third cluster")]

for lat,lng,nameP in latLong:
    point_layer.add_child(folium.CircleMarker(location=[lat, lng], radius=2,
        popup=str(nameP) + " Lat: " + str(lat) + " , Long: " + str(lng), 
        tooltip=str(nameP) + " Lat: " + str(lat) + " , Long: " + str(lng),
        fill=True,  # Set fill to True
        color='red',
        fill_opacity=1)).add_to(ny_map)
    
ny_map.add_child(point_layer)
ny_map.add_child(folium.LayerControl()) 
    
ny_map.save("mymapE3.html")

# %%
# cluster visualzie #Euclidean k=4
latitude=40.428
longitude=-74.1
dir_E4 = glob.glob('/Users/hanzheyu/Desktop/CSE427-project/NY_pickup/result4E/4E/points/*.txt')
df = pd.concat([pd.read_csv(f, sep=" ", header=None) for f in dir_E4])
df.rename({0:'classify', 1: 'lat', 2: 'lon'})
df.columns = ['classify','lat', 'lon']
df = df.iloc[1:25000,[0,1,2]]
df0 = df[df.classify==0]

df1 = df[df.classify==1]

df2 = df[df.classify==2]

df3 = df[df.classify==3]


incidents=folium.map.FeatureGroup()

for lat,lon, in zip(df0.lat,df0.lon):
        incidents.add_child(
            folium.CircleMarker(
            [lat,lon],
            radius=0.1,
            color='yellow',
            fill=True,
            fill_color='yellow',
            fill_opacity=4
            )
 )
        
for lat,lon, in zip(df1.lat,df1.lon):
        incidents.add_child(
            folium.CircleMarker(
            [lat,lon],
            radius=0.1,
            color='blue',
            fill=True,
            fill_color='blue',
            fill_opacity=4
            )
        
        )
for lat,lon, in zip(df2.lat,df2.lon):
        incidents.add_child(
            folium.CircleMarker(
            [lat,lon],
            radius=0.1,
            color='green',
            fill=True,
            fill_color='green',
            fill_opacity=4
            )
        
        )
        
for lat,lon, in zip(df3.lat,df3.lon):
        incidents.add_child(
            folium.CircleMarker(
            [lat,lon],
            radius=0.1,
            color='teal',
            fill=True,
            fill_color='teal',
            fill_opacity=4
            )
        
        )

# m = folium.Map(location=[39.712183, -104.998424], zoom_start=5)
# point_layer = folium.FeatureGroup(name="Query Search")


ny_map=folium.Map(location=[latitude,longitude],zoom_start=12)
ny_map.add_child(incidents)
point_layer = folium.FeatureGroup(name="Query Search")

latLong = [(40.7259458866, -73.9957766891,"first cluster"),
           (40.7555629901, -73.9828450696,"second cluster"),
           (40.7791520213, -73.9597003892,"third cluster"),
           (40.711130598, -73.8285880275,"fourth cluster"),]

for lat,lng,nameP in latLong:
    point_layer.add_child(folium.CircleMarker(location=[lat, lng], radius=2,
        popup=str(nameP) + " Lat: " + str(lat) + " , Long: " + str(lng), 
        tooltip=str(nameP) + " Lat: " + str(lat) + " , Long: " + str(lng),
        fill=True,  # Set fill to True
        color='red',
        fill_opacity=1)).add_to(ny_map)
    
ny_map.add_child(point_layer)
ny_map.add_child(folium.LayerControl()) 
    
ny_map.save("mymapE4.html")

# %%
# cluster visualzie #Euclidean k=5
latitude=40.428
longitude=-74.1
dir_E5 = glob.glob('/Users/hanzheyu/Desktop/CSE427-project/NY_pickup/result5E/5E/points/*.txt')
df = pd.concat([pd.read_csv(f, sep=" ", header=None) for f in dir_E5])
df.rename({0:'classify', 1: 'lat', 2: 'lon'})
df.columns = ['classify','lat', 'lon']
df = df.iloc[1:30000,[0,1,2]]
df0 = df[df.classify==0]

df1 = df[df.classify==1]

df2 = df[df.classify==2]

df3 = df[df.classify==3]

df4 = df[df.classify==4]

incidents=folium.map.FeatureGroup()

for lat,lon, in zip(df0.lat,df0.lon):
        incidents.add_child(
            folium.CircleMarker(
            [lat,lon],
            radius=0.1,
            color='yellow',
            fill=True,
            fill_color='yellow',
            fill_opacity=4
            )
 )
        
for lat,lon, in zip(df1.lat,df1.lon):
        incidents.add_child(
            folium.CircleMarker(
            [lat,lon],
            radius=0.1,
            color='blue',
            fill=True,
            fill_color='blue',
            fill_opacity=4
            )
        
        )
for lat,lon, in zip(df2.lat,df2.lon):
        incidents.add_child(
            folium.CircleMarker(
            [lat,lon],
            radius=0.1,
            color='green',
            fill=True,
            fill_color='green',
            fill_opacity=4
            )
        
        )
        
for lat,lon, in zip(df3.lat,df3.lon):
        incidents.add_child(
            folium.CircleMarker(
            [lat,lon],
            radius=0.1,
            color='teal',
            fill=True,
            fill_color='teal',
            fill_opacity=4
            )
        
        )
        
for lat,lon, in zip(df4.lat,df4.lon):
        incidents.add_child(
            folium.CircleMarker(
            [lat,lon],
            radius=0.1,
            color='silver',
            fill=True,
            fill_color='silver',
            fill_opacity=4
            )
        
        )
# m = folium.Map(location=[39.712183, -104.998424], zoom_start=5)
# point_layer = folium.FeatureGroup(name="Query Search")


ny_map=folium.Map(location=[latitude,longitude],zoom_start=12)
ny_map.add_child(incidents)
point_layer = folium.FeatureGroup(name="Query Search")

latLong = [(40.7445266274,-73.9911980457,"first cluster"),
           (40.762409951, -73.9768879648,"second cluster"),
           (40.7110194904, -73.8284233181,"third cluster"),
           (40.7189408681, -73.9963856339,"fourth cluster"),
           (40.7814239857, -73.9566717553, "fifth cluster")]

for lat,lng,nameP in latLong:
    point_layer.add_child(folium.CircleMarker(location=[lat, lng], radius=2,
        popup=str(nameP) + " Lat: " + str(lat) + " , Long: " + str(lng), 
        tooltip=str(nameP) + " Lat: " + str(lat) + " , Long: " + str(lng),
        fill=True,  # Set fill to True
        color='red',
        fill_opacity=1)).add_to(ny_map)
    
ny_map.add_child(point_layer)
ny_map.add_child(folium.LayerControl()) 
    
ny_map.save("mymapE5.html")

# %%
# cluster visualzie #Euclidean k=6
latitude=40.428
longitude=-74.1
dir_E6 = glob.glob('/Users/hanzheyu/Desktop/CSE427-project/NY_pickup/result6E/6E/points/*.txt')
df = pd.concat([pd.read_csv(f, sep=" ", header=None) for f in dir_E6])
df.rename({0:'classify', 1: 'lat', 2: 'lon'})
df.columns = ['classify','lat', 'lon']
df = df.iloc[1:25000,[0,1,2]]

df0 = df[df.classify==0]

df1 = df[df.classify==1]

df2 = df[df.classify==2]

df3 = df[df.classify==3]

df4 = df[df.classify==4]

df5 = df[df.classify==5]


incidents=folium.map.FeatureGroup()

for lat,lon, in zip(df0.lat,df0.lon):
        incidents.add_child(
            folium.CircleMarker(
            [lat,lon],
            radius=0.1,
            color='yellow',
            fill=True,
            fill_color='yellow',
            fill_opacity=4
            )
 )
        
for lat,lon, in zip(df1.lat,df1.lon):
        incidents.add_child(
            folium.CircleMarker(
            [lat,lon],
            radius=0.1,
            color='blue',
            fill=True,
            fill_color='blue',
            fill_opacity=4
            )
        
        )
for lat,lon, in zip(df2.lat,df2.lon):
        incidents.add_child(
            folium.CircleMarker(
            [lat,lon],
            radius=0.1,
            color='green',
            fill=True,
            fill_color='green',
            fill_opacity=4
            )
        
        )
        
for lat,lon, in zip(df3.lat,df3.lon):
        incidents.add_child(
            folium.CircleMarker(
            [lat,lon],
            radius=0.1,
            color='teal',
            fill=True,
            fill_color='teal',
            fill_opacity=4
            )
        
        )
        
for lat,lon, in zip(df4.lat,df4.lon):
        incidents.add_child(
            folium.CircleMarker(
            [lat,lon],
            radius=0.1,
            color='silver',
            fill=True,
            fill_color='silver',
            fill_opacity=4
            )
        
        )
        
for lat,lon, in zip(df5.lat,df5.lon):
        incidents.add_child(
            folium.CircleMarker(
            [lat,lon],
            radius=0.1,
            color='magenta',
            fill=True,
            fill_color='magenta',
            fill_opacity=4
            )
        
        )
# m = folium.Map(location=[39.712183, -104.998424], zoom_start=5)
# point_layer = folium.FeatureGroup(name="Query Search")


ny_map=folium.Map(location=[latitude,longitude],zoom_start=12)
ny_map.add_child(incidents)
point_layer = folium.FeatureGroup(name="Query Search")

latLong = [(40.7513670507, -73.9873332113,"first cluster"),
           (40.7655932369, -73.9745509476,"second cluster"),
           (40.7314850962, -73.9927049172,"third cluster"),
           (40.7109595417, -73.8283582151,"fourth cluster"),
           (40.7819322731, -73.9553523962, "fifth cluster"),
           (40.7080247663, -74.0040880039, "sixth cluster")]

for lat,lng,nameP in latLong:
    point_layer.add_child(folium.CircleMarker(location=[lat, lng], radius=2,
        popup=str(nameP) + " Lat: " + str(lat) + " , Long: " + str(lng), 
        tooltip=str(nameP) + " Lat: " + str(lat) + " , Long: " + str(lng),
        fill=True,  # Set fill to True
        color='red',
        fill_opacity=1)).add_to(ny_map)
    
ny_map.add_child(point_layer)
ny_map.add_child(folium.LayerControl()) 
    
ny_map.save("mymapE6.html")

# %%
# cluster visualzie #Euclidean k=7
latitude=40.428
longitude=-74.1
dir_E7 = glob.glob('/Users/hanzheyu/Desktop/CSE427-project/NY_pickup/result7E/7E/points/*.txt')
df = pd.concat([pd.read_csv(f, sep=" ", header=None) for f in dir_E7])
df.rename({0:'classify', 1: 'lat', 2: 'lon'})
df.columns = ['classify','lat', 'lon']
df = df.iloc[1:25000,[0,1,2]]

df0 = df[df.classify==0]

df1 = df[df.classify==1]

df2 = df[df.classify==2]

df3 = df[df.classify==3]

df4 = df[df.classify==4]

df5 = df[df.classify==5]

df6 = df[df.classify==6]


incidents=folium.map.FeatureGroup()

for lat,lon, in zip(df0.lat,df0.lon):
        incidents.add_child(
            folium.CircleMarker(
            [lat,lon],
            radius=0.1,
            color='yellow',
            fill=True,
            fill_color='yellow',
            fill_opacity=4
            )
 )
        
for lat,lon, in zip(df1.lat,df1.lon):
        incidents.add_child(
            folium.CircleMarker(
            [lat,lon],
            radius=0.1,
            color='blue',
            fill=True,
            fill_color='blue',
            fill_opacity=4
            )
        
        )
for lat,lon, in zip(df2.lat,df2.lon):
        incidents.add_child(
            folium.CircleMarker(
            [lat,lon],
            radius=0.1,
            color='green',
            fill=True,
            fill_color='green',
            fill_opacity=4
            )
        
        )
        
for lat,lon, in zip(df3.lat,df3.lon):
        incidents.add_child(
            folium.CircleMarker(
            [lat,lon],
            radius=0.1,
            color='teal',
            fill=True,
            fill_color='teal',
            fill_opacity=4
            )
        
        )
        
for lat,lon, in zip(df4.lat,df4.lon):
        incidents.add_child(
            folium.CircleMarker(
            [lat,lon],
            radius=0.1,
            color='silver',
            fill=True,
            fill_color='silver',
            fill_opacity=4
            )
        
        )
        
for lat,lon, in zip(df5.lat,df5.lon):
        incidents.add_child(
            folium.CircleMarker(
            [lat,lon],
            radius=0.1,
            color='magenta',
            fill=True,
            fill_color='magenta',
            fill_opacity=4
            )
        
        )

for lat,lon, in zip(df6.lat,df6.lon):
        incidents.add_child(
            folium.CircleMarker(
            [lat,lon],
            radius=0.1,
            color='cyan',
            fill=True,
            fill_color='cyan',
            fill_opacity=4
            )
        
        )
# m = folium.Map(location=[39.712183, -104.998424], zoom_start=5)
# point_layer = folium.FeatureGroup(name="Query Search")


ny_map=folium.Map(location=[latitude,longitude],zoom_start=12)
ny_map.add_child(incidents)
point_layer = folium.FeatureGroup(name="Query Search")

latLong = [(40.7687023638,-73.8742019725,"first cluster"),
           (40.7812867314,-73.9586683561,"second cluster"),
           (40.6471220556,-73.7839629579,"third cluster"),
           (40.6941681289,-73.9685861385,"fourth cluster"),
           (40.7424241117,-73.9910714767, "fifth cluster"),
           (40.7612729815,-73.9782824791, "sixth cluster"),
           (40.7211008381,-74.0009961024, "seventh cluster"),]

for lat,lng,nameP in latLong:
    point_layer.add_child(folium.CircleMarker(location=[lat, lng], radius=2,
        popup=str(nameP) + " Lat: " + str(lat) + " , Long: " + str(lng), 
        tooltip=str(nameP) + " Lat: " + str(lat) + " , Long: " + str(lng),
        fill=True,  # Set fill to True
        color='red',
        fill_opacity=1)).add_to(ny_map)
    
ny_map.add_child(point_layer)
ny_map.add_child(folium.LayerControl()) 
    
ny_map.save("mymapE7.html")

# %%
# cluster visualzie #Euclidean k=8
latitude=40.428
longitude=-74.1
dir_E7 = glob.glob('/Users/hanzheyu/Desktop/CSE427-project/NY_pickup/result8E/8E/points/*.txt')
df = pd.concat([pd.read_csv(f, sep=" ", header=None) for f in dir_E7])
df.rename({0:'classify', 1: 'lat', 2: 'lon'})
df.columns = ['classify','lat', 'lon']
df = df.iloc[1:25000,[0,1,2]]

df0 = df[df.classify==0]

df1 = df[df.classify==1]

df2 = df[df.classify==2]

df3 = df[df.classify==3]

df4 = df[df.classify==4]

df5 = df[df.classify==5]

df6 = df[df.classify==6]

df7 = df[df.classify==7]

incidents=folium.map.FeatureGroup()

for lat,lon, in zip(df0.lat,df0.lon):
        incidents.add_child(
            folium.CircleMarker(
            [lat,lon],
            radius=0.1,
            color='yellow',
            fill=True,
            fill_color='yellow',
            fill_opacity=4
            )
 )
        
for lat,lon, in zip(df1.lat,df1.lon):
        incidents.add_child(
            folium.CircleMarker(
            [lat,lon],
            radius=0.1,
            color='blue',
            fill=True,
            fill_color='blue',
            fill_opacity=4
            )
        
        )
for lat,lon, in zip(df2.lat,df2.lon):
        incidents.add_child(
            folium.CircleMarker(
            [lat,lon],
            radius=0.1,
            color='green',
            fill=True,
            fill_color='green',
            fill_opacity=4
            )
        
        )
        
for lat,lon, in zip(df3.lat,df3.lon):
        incidents.add_child(
            folium.CircleMarker(
            [lat,lon],
            radius=0.1,
            color='teal',
            fill=True,
            fill_color='teal',
            fill_opacity=4
            )
        
        )
        
for lat,lon, in zip(df4.lat,df4.lon):
        incidents.add_child(
            folium.CircleMarker(
            [lat,lon],
            radius=0.1,
            color='silver',
            fill=True,
            fill_color='silver',
            fill_opacity=4
            )
        
        )
        
for lat,lon, in zip(df5.lat,df5.lon):
        incidents.add_child(
            folium.CircleMarker(
            [lat,lon],
            radius=0.1,
            color='magenta',
            fill=True,
            fill_color='magenta',
            fill_opacity=4
            )
        
        )

for lat,lon, in zip(df6.lat,df6.lon):
        incidents.add_child(
            folium.CircleMarker(
            [lat,lon],
            radius=0.1,
            color='cyan',
            fill=True,
            fill_color='cyan',
            fill_opacity=4
            )
        
        )
        
for lat,lon, in zip(df7.lat,df7.lon):
        incidents.add_child(
            folium.CircleMarker(
            [lat,lon],
            radius=0.1,
            color='pink',
            fill=True,
            fill_color='pink',
            fill_opacity=4
            )
        
        )
# m = folium.Map(location=[39.712183, -104.998424], zoom_start=5)
# point_layer = folium.FeatureGroup(name="Query Search")


ny_map=folium.Map(location=[latitude,longitude],zoom_start=12)
ny_map.add_child(incidents)
point_layer = folium.FeatureGroup(name="Query Search")

latLong = [(40.7719023905,-73.9814581181,"first cluster"),
           (40.7885840593,-73.9569277193,"second cluster"),
           (40.7080715352,-74.0039796365,"third cluster"),
           (40.7635963027,-73.9623603666,"fourth cluster"),
           (40.7688231477,-73.8730079099, "fifth cluster"),
           (40.7517297852,-73.9858873536, "sixth cluster"),
           (40.7320309112,-73.9931787156, "seventh cluster"),
           (40.647091468,-73.7840381428, "eighth cluster")]

for lat,lng,nameP in latLong:
    point_layer.add_child(folium.CircleMarker(location=[lat, lng], radius=2,
        popup=str(nameP) + " Lat: " + str(lat) + " , Long: " + str(lng), 
        tooltip=str(nameP) + " Lat: " + str(lat) + " , Long: " + str(lng),
        fill=True,  # Set fill to True
        color='red',
        fill_opacity=1)).add_to(ny_map)
    
ny_map.add_child(point_layer)
ny_map.add_child(folium.LayerControl()) 
    
ny_map.save("/Users/hanzheyu/Desktop/CSE427-project/screenshot/mymapE8.html")
